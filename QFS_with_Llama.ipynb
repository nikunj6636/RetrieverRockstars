# %%
# !pip3 install optimum
# Out:
# Collecting optimum
#   Downloading optimum-1.22.0-py3-none-any.whl.metadata (20 kB)
# Collecting coloredlogs (from optimum)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from optimum) (1.13.3)
# Requirement already satisfied: transformers<4.45.0,>=4.29 in /opt/conda/lib/python3.10/site-packages (from transformers[sentencepiece]<4.45.0,>=4.29->optimum) (4.44.2)
# Requirement already satisfied: torch>=1.11 in /opt/conda/lib/python3.10/site-packages (from optimum) (2.4.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from optimum) (21.3)
# Requirement already satisfied: numpy<2.0 in /opt/conda/lib/python3.10/site-packages (from optimum) (1.26.4)
# Requirement already satisfied: huggingface-hub>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from optimum) (0.25.0)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (from optimum) (3.0.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.8.0->optimum) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.8.0->optimum) (2024.6.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.8.0->optimum) (6.0.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.8.0->optimum) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.8.0->optimum) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.8.0->optimum) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->optimum) (3.1.2)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.11->optimum) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.11->optimum) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers<4.45.0,>=4.29->transformers[sentencepiece]<4.45.0,>=4.29->optimum) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers<4.45.0,>=4.29->transformers[sentencepiece]<4.45.0,>=4.29->optimum) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers<4.45.0,>=4.29->transformers[sentencepiece]<4.45.0,>=4.29->optimum) (0.19.1)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.10/site-packages (from transformers[sentencepiece]<4.45.0,>=4.29->optimum) (3.20.3)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /opt/conda/lib/python3.10/site-packages (from transformers[sentencepiece]<4.45.0,>=4.29->optimum) (0.2.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->optimum)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets->optimum) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets->optimum) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets->optimum) (2.2.2)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets->optimum) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets->optimum) (0.70.16)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets->optimum) (3.9.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->optimum) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->optimum) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->optimum) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->optimum) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->optimum) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->optimum) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->optimum) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.8.0->optimum) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.8.0->optimum) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.8.0->optimum) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.8.0->optimum) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.11->optimum) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->optimum) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->optimum) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->optimum) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets->optimum) (1.16.0)
# Downloading optimum-1.22.0-py3-none-any.whl (453 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.7/453.7 kB 12.4 MB/s eta 0:00:0000:01
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.9 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.6 MB/s eta 0:00:00
# Installing collected packages: humanfriendly, coloredlogs, optimum
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 optimum-1.22.0

# %%
# !pip3 install auto-gptq
# Out:
# Collecting auto-gptq
#   Downloading auto_gptq-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: accelerate>=0.26.0 in /opt/conda/lib/python3.10/site-packages (from auto-gptq) (0.34.2)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (from auto-gptq) (3.0.0)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from auto-gptq) (0.2.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from auto-gptq) (1.26.4)
# Collecting rouge (from auto-gptq)
#   Downloading rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting gekko (from auto-gptq)
#   Downloading gekko-1.2.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: torch>=1.13.0 in /opt/conda/lib/python3.10/site-packages (from auto-gptq) (2.4.0)
# Requirement already satisfied: safetensors in /opt/conda/lib/python3.10/site-packages (from auto-gptq) (0.4.5)
# Requirement already satisfied: transformers>=4.31.0 in /opt/conda/lib/python3.10/site-packages (from auto-gptq) (4.44.2)
# Collecting peft>=0.5.0 (from auto-gptq)
#   Downloading peft-0.13.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from auto-gptq) (4.66.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.26.0->auto-gptq) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.26.0->auto-gptq) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.26.0->auto-gptq) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.26.0->auto-gptq) (0.25.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->auto-gptq) (2024.6.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->auto-gptq) (2024.5.15)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->auto-gptq) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.31.0->auto-gptq) (0.19.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets->auto-gptq) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets->auto-gptq) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets->auto-gptq) (2.2.2)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets->auto-gptq) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets->auto-gptq) (0.70.16)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets->auto-gptq) (3.9.5)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from rouge->auto-gptq) (1.16.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->auto-gptq) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->auto-gptq) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->auto-gptq) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->auto-gptq) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->auto-gptq) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->auto-gptq) (4.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->accelerate>=0.26.0->auto-gptq) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->auto-gptq) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->auto-gptq) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->auto-gptq) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers>=4.31.0->auto-gptq) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.13.0->auto-gptq) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->auto-gptq) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->auto-gptq) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->auto-gptq) (2024.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.13.0->auto-gptq) (1.3.0)
# Downloading auto_gptq-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 69.1 MB/s eta 0:00:00:00:0100:01
# Downloading peft-0.13.0-py3-none-any.whl (322 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.5/322.5 kB 20.5 MB/s eta 0:00:00
# Downloading gekko-1.2.1-py3-none-any.whl (13.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 85.6 MB/s eta 0:00:00:00:0100:01
# Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Installing collected packages: rouge, gekko, peft, auto-gptq
# Successfully installed auto-gptq-0.7.1 gekko-1.2.1 peft-0.13.0 rouge-1.0.1

# %%
# !pip3 install langchain
# Out:
# Collecting langchain
#   Downloading langchain-0.3.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in /opt/conda/lib/python3.10/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/conda/lib/python3.10/site-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/conda/lib/python3.10/site-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from langchain) (4.0.3)
# Collecting langchain-core<0.4.0,>=0.3.6 (from langchain)
#   Downloading langchain_core-0.3.6-py3-none-any.whl.metadata (6.3 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.0 (from langchain)
#   Downloading langchain_text_splitters-0.3.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.129-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1 in /opt/conda/lib/python3.10/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/conda/lib/python3.10/site-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in /opt/conda/lib/python3.10/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /opt/conda/lib/python3.10/site-packages (from langchain) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain) (1.33)
# Collecting packaging<25,>=23.2 (from langchain-core<0.4.0,>=0.3.6->langchain)
#   Downloading packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/conda/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/conda/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (4.4.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.5)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.6->langchain) (2.4)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.0)
# Downloading langchain-0.3.1-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 22.2 MB/s eta 0:00:0000:01
# Downloading langchain_core-0.3.6-py3-none-any.whl (399 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.9/399.9 kB 25.9 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.3.0-py3-none-any.whl (25 kB)
# Downloading langsmith-0.1.129-py3-none-any.whl (292 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.2/292.2 kB 18.3 MB/s eta 0:00:00
# Downloading packaging-24.1-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: packaging, langsmith, langchain-core, langchain-text-splitters, langchain
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 24.8.3 requires cubinlinker, which is not installed.
# cudf 24.8.3 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 24.8.3 requires ptxcompiler, which is not installed.
# cuml 24.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 24.8.3 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 24.8.3 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.6.0 which is incompatible.
# distributed 2024.7.1 requires dask==2024.7.1, but you have dask 2024.9.0 which is incompatible.
# google-cloud-bigquery 2.34.4 requires packaging<22.0dev,>=14.3, but you have packaging 24.1 which is incompatible.
# jupyterlab 4.2.5 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# rapids-dask-dependency 24.8.0a0 requires dask==2024.7.1, but you have dask 2024.9.0 which is incompatible.
# ydata-profiling 4.10.0 requires scipy<1.14,>=1.4.1, but you have scipy 1.14.1 which is incompatible.
# Successfully installed langchain-0.3.1 langchain-core-0.3.6 langchain-text-splitters-0.3.0 langsmith-0.1.129 packaging-24.1

# %%
# !pip3 install langchain_community
# Out:
# Collecting langchain_community
#   Downloading langchain_community-0.3.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: PyYAML>=5.3 in /opt/conda/lib/python3.10/site-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/conda/lib/python3.10/site-packages (from langchain_community) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/conda/lib/python3.10/site-packages (from langchain_community) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/conda/lib/python3.10/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: langchain<0.4.0,>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from langchain_community) (0.3.1)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.6 in /opt/conda/lib/python3.10/site-packages (from langchain_community) (0.3.6)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /opt/conda/lib/python3.10/site-packages (from langchain_community) (0.1.129)
# Requirement already satisfied: numpy<2,>=1 in /opt/conda/lib/python3.10/site-packages (from langchain_community) (1.26.4)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain_community)
#   Downloading pydantic_settings-2.5.2-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: requests<3,>=2 in /opt/conda/lib/python3.10/site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /opt/conda/lib/python3.10/site-packages (from langchain_community) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from langchain<0.4.0,>=0.3.1->langchain_community) (0.3.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/conda/lib/python3.10/site-packages (from langchain<0.4.0,>=0.3.1->langchain_community) (2.9.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain_community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain_community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.125->langchain_community) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/conda/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.125->langchain_community) (3.10.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/conda/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain_community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain_community) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain_community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.0.3)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (4.4.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (1.0.5)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.6->langchain_community) (2.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.1->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/conda/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.1->langchain_community) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (1.2.0)
# Downloading langchain_community-0.3.1-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 27.5 MB/s eta 0:00:0000:0100:01
# Downloading pydantic_settings-2.5.2-py3-none-any.whl (26 kB)
# Installing collected packages: pydantic-settings, langchain_community
# Successfully installed langchain_community-0.3.1 pydantic-settings-2.5.2

# %%
import torch
from langchain import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, GenerationConfig, pipeline
import optimum
 
MODEL_NAME = "TheBloke/Llama-2-13b-Chat-GPTQ"
 
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME, use_fast=True)
 
model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME, torch_dtype=torch.float16, trust_remote_code=True, device_map="auto"
)
 
generation_config = GenerationConfig.from_pretrained(MODEL_NAME)
generation_config.max_new_tokens = 1024
generation_config.temperature = 0.0001
generation_config.top_p = 0.95
generation_config.do_sample = True
generation_config.repetition_penalty = 1.15
 
text_pipeline = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    generation_config=generation_config,
)
 
llm = HuggingFacePipeline(pipeline=text_pipeline, model_kwargs={"temperature": 0})
# Out:
# tokenizer_config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/411 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama_fast.LlamaTokenizerFast'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565 - if you loaded a llama tokenizer from a GGUF file you can ignore this message.
# config.json:   0%|          | 0.00/837 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/7.26G [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/transformers/modeling_utils.py:4713: FutureWarning: `_is_quantized_training_enabled` is going to be deprecated in transformers 4.39.0. Please use `model.hf_quantizer.is_trainable` instead
#   warnings.warn(
# Some weights of the model checkpoint at TheBloke/Llama-2-13b-Chat-GPTQ were not used when initializing LlamaForCausalLM: ['model.layers.0.mlp.down_proj.bias', 'model.layers.0.mlp.gate_proj.bias', 'model.layers.0.mlp.up_proj.bias', 'model.layers.0.self_attn.k_proj.bias', 'model.layers.0.self_attn.o_proj.bias', 'model.layers.0.self_attn.q_proj.bias', 'model.layers.0.self_attn.v_proj.bias', 'model.layers.1.mlp.down_proj.bias', 'model.layers.1.mlp.gate_proj.bias', 'model.layers.1.mlp.up_proj.bias', 'model.layers.1.self_attn.k_proj.bias', 'model.layers.1.self_attn.o_proj.bias', 'model.layers.1.self_attn.q_proj.bias', 'model.layers.1.self_attn.v_proj.bias', 'model.layers.10.mlp.down_proj.bias', 'model.layers.10.mlp.gate_proj.bias', 'model.layers.10.mlp.up_proj.bias', 'model.layers.10.self_attn.k_proj.bias', 'model.layers.10.self_attn.o_proj.bias', 'model.layers.10.self_attn.q_proj.bias', 'model.layers.10.self_attn.v_proj.bias', 'model.layers.11.mlp.down_proj.bias', 'model.layers.11.mlp.gate_proj.bias', 'model.layers.11.mlp.up_proj.bias', 'model.layers.11.self_attn.k_proj.bias', 'model.layers.11.self_attn.o_proj.bias', 'model.layers.11.self_attn.q_proj.bias', 'model.layers.11.self_attn.v_proj.bias', 'model.layers.12.mlp.down_proj.bias', 'model.layers.12.mlp.gate_proj.bias', 'model.layers.12.mlp.up_proj.bias', 'model.layers.12.self_attn.k_proj.bias', 'model.layers.12.self_attn.o_proj.bias', 'model.layers.12.self_attn.q_proj.bias', 'model.layers.12.self_attn.v_proj.bias', 'model.layers.13.mlp.down_proj.bias', 'model.layers.13.mlp.gate_proj.bias', 'model.layers.13.mlp.up_proj.bias', 'model.layers.13.self_attn.k_proj.bias', 'model.layers.13.self_attn.o_proj.bias', 'model.layers.13.self_attn.q_proj.bias', 'model.layers.13.self_attn.v_proj.bias', 'model.layers.14.mlp.down_proj.bias', 'model.layers.14.mlp.gate_proj.bias', 'model.layers.14.mlp.up_proj.bias', 'model.layers.14.self_attn.k_proj.bias', 'model.layers.14.self_attn.o_proj.bias', 'model.layers.14.self_attn.q_proj.bias', 'model.layers.14.self_attn.v_proj.bias', 'model.layers.15.mlp.down_proj.bias', 'model.layers.15.mlp.gate_proj.bias', 'model.layers.15.mlp.up_proj.bias', 'model.layers.15.self_attn.k_proj.bias', 'model.layers.15.self_attn.o_proj.bias', 'model.layers.15.self_attn.q_proj.bias', 'model.layers.15.self_attn.v_proj.bias', 'model.layers.16.mlp.down_proj.bias', 'model.layers.16.mlp.gate_proj.bias', 'model.layers.16.mlp.up_proj.bias', 'model.layers.16.self_attn.k_proj.bias', 'model.layers.16.self_attn.o_proj.bias', 'model.layers.16.self_attn.q_proj.bias', 'model.layers.16.self_attn.v_proj.bias', 'model.layers.17.mlp.down_proj.bias', 'model.layers.17.mlp.gate_proj.bias', 'model.layers.17.mlp.up_proj.bias', 'model.layers.17.self_attn.k_proj.bias', 'model.layers.17.self_attn.o_proj.bias', 'model.layers.17.self_attn.q_proj.bias', 'model.layers.17.self_attn.v_proj.bias', 'model.layers.18.mlp.down_proj.bias', 'model.layers.18.mlp.gate_proj.bias', 'model.layers.18.mlp.up_proj.bias', 'model.layers.18.self_attn.k_proj.bias', 'model.layers.18.self_attn.o_proj.bias', 'model.layers.18.self_attn.q_proj.bias', 'model.layers.18.self_attn.v_proj.bias', 'model.layers.19.mlp.down_proj.bias', 'model.layers.19.mlp.gate_proj.bias', 'model.layers.19.mlp.up_proj.bias', 'model.layers.19.self_attn.k_proj.bias', 'model.layers.19.self_attn.o_proj.bias', 'model.layers.19.self_attn.q_proj.bias', 'model.layers.19.self_attn.v_proj.bias', 'model.layers.2.mlp.down_proj.bias', 'model.layers.2.mlp.gate_proj.bias', 'model.layers.2.mlp.up_proj.bias', 'model.layers.2.self_attn.k_proj.bias', 'model.layers.2.self_attn.o_proj.bias', 'model.layers.2.self_attn.q_proj.bias', 'model.layers.2.self_attn.v_proj.bias', 'model.layers.20.mlp.down_proj.bias', 'model.layers.20.mlp.gate_proj.bias', 'model.layers.20.mlp.up_proj.bias', 'model.layers.20.self_attn.k_proj.bias', 'model.layers.20.self_attn.o_proj.bias', 'model.layers.20.self_attn.q_proj.bias', 'model.layers.20.self_attn.v_proj.bias', 'model.layers.21.mlp.down_proj.bias ...
# - This IS expected if you are initializing LlamaForCausalLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LlamaForCausalLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# /tmp/ipykernel_30/3452042105.py:28: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFacePipeline``.
#   llm = HuggingFacePipeline(pipeline=text_pipeline, model_kwargs={"temperature": 0})

# %% [markdown]
# ### Query-Focused Summarization Paper Code

# %%
# !pip3 install cdlib
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Collecting cdlib
#   Downloading cdlib-0.4.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from cdlib) (1.26.4)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from cdlib) (1.2.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from cdlib) (4.66.4)
# Requirement already satisfied: networkx>=3.0 in /opt/conda/lib/python3.10/site-packages (from cdlib) (3.3)
# Collecting demon (from cdlib)
#   Downloading demon-2.0.6-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-louvain>=0.16 in /opt/conda/lib/python3.10/site-packages (from cdlib) (0.16)
# Requirement already satisfied: scipy>=1.10 in /opt/conda/lib/python3.10/site-packages (from cdlib) (1.14.1)
# Collecting pulp (from cdlib)
#   Downloading PuLP-2.9.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.10/site-packages (from cdlib) (0.12.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from cdlib) (2.2.2)
# Collecting eva-lcd (from cdlib)
#   Downloading eva_lcd-0.1.1-py3-none-any.whl.metadata (731 bytes)
# Collecting bimlpa (from cdlib)
#   Downloading bimlpa-0.1.2-py3-none-any.whl.metadata (725 bytes)
# Collecting python-igraph>=0.10 (from cdlib)
#   Downloading python_igraph-0.11.6-py3-none-any.whl.metadata (2.8 kB)
# Collecting angelcommunity (from cdlib)
#   Downloading angelcommunity-2.0.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: pooch in /opt/conda/lib/python3.10/site-packages (from cdlib) (1.8.2)
# Collecting dynetx (from cdlib)
#   Downloading dynetx-0.3.2-py3-none-any.whl.metadata (2.9 kB)
# Collecting thresholdclustering (from cdlib)
#   Downloading thresholdclustering-1.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting python-Levenshtein (from cdlib)
#   Downloading python_Levenshtein-0.26.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.10/site-packages (from cdlib) (5.22.0)
# Requirement already satisfied: igraph==0.11.6 in /opt/conda/lib/python3.10/site-packages (from python-igraph>=0.10->cdlib) (0.11.6)
# Requirement already satisfied: texttable>=1.6.2 in /opt/conda/lib/python3.10/site-packages (from igraph==0.11.6->python-igraph>=0.10->cdlib) (1.7.0)
# Requirement already satisfied: future in /opt/conda/lib/python3.10/site-packages (from angelcommunity->cdlib) (1.0.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from bimlpa->cdlib) (3.7.5)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from dynetx->cdlib) (5.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->cdlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->cdlib) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->cdlib) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from plotly->cdlib) (8.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from plotly->cdlib) (24.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/conda/lib/python3.10/site-packages (from pooch->cdlib) (3.11.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from pooch->cdlib) (2.32.3)
# Collecting Levenshtein==0.26.0 (from python-Levenshtein->cdlib)
#   Downloading levenshtein-0.26.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting rapidfuzz<4.0.0,>=3.9.0 (from Levenshtein==0.26.0->python-Levenshtein->cdlib)
#   Downloading rapidfuzz-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->cdlib) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->cdlib) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bimlpa->cdlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bimlpa->cdlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bimlpa->cdlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bimlpa->cdlib) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bimlpa->cdlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bimlpa->cdlib) (3.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->cdlib) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch->cdlib) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch->cdlib) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch->cdlib) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch->cdlib) (2024.8.30)
# Downloading cdlib-0.4.0-py3-none-any.whl (263 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.6/263.6 kB 6.6 MB/s eta 0:00:00a 0:00:01
# Downloading python_igraph-0.11.6-py3-none-any.whl (9.1 kB)
# Downloading angelcommunity-2.0.0-py3-none-any.whl (10 kB)
# Downloading bimlpa-0.1.2-py3-none-any.whl (7.0 kB)
# Downloading demon-2.0.6-py3-none-any.whl (7.3 kB)
# Downloading dynetx-0.3.2-py3-none-any.whl (39 kB)
# Downloading eva_lcd-0.1.1-py3-none-any.whl (9.2 kB)
# Downloading PuLP-2.9.0-py3-none-any.whl (17.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 78.8 MB/s eta 0:00:00:00:0100:01
# Downloading python_Levenshtein-0.26.0-py3-none-any.whl (9.4 kB)
# Downloading levenshtein-0.26.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 11.2 MB/s eta 0:00:00
# Downloading thresholdclustering-1.1-py3-none-any.whl (5.3 kB)
# Downloading rapidfuzz-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 81.2 MB/s eta 0:00:00:00:01
# Installing collected packages: thresholdclustering, rapidfuzz, pulp, eva-lcd, dynetx, demon, python-igraph, Levenshtein, python-Levenshtein, bimlpa, angelcommunity, cdlib
# Successfully installed Levenshtein-0.26.0 angelcommunity-2.0.0 bimlpa-0.1.2 cdlib-0.4.0 demon-2.0.6 dynetx-0.3.2 eva-lcd-0.1.1 pulp-2.9.0 python-Levenshtein-0.26.0 python-igraph-0.11.6 rapidfuzz-3.10.0 thresholdclustering-1.1

# %%
import networkx as nx
from cdlib import algorithms
import os
import shutil
from langchain import PromptTemplate

# %%
# 1. Source Documents → Text Chunks
def split_documents_into_chunks(documents, chunk_size=600, overlap_size=100):
    chunks = []
    for document in documents:
        for i in range(0, len(document), chunk_size - overlap_size):
            chunk = document[i: i+chunk_size]
            chunks.append(chunk)
    return chunks

# %%
# 2. Text Chunks → Element Instances
def extract_elements_from_chunks(chunks):
    elements = []
    template = """
    <s>[INST] <<SYS>>
    Extract entities and relationships from the following text.
    <</SYS>>

    {text} [/INST]
    """


    prompt = PromptTemplate(
        input_variables=["text"],
        template=template,
    )
        
    for index, chunk in enumerate(chunks):
        print(f"Chunk index {index} of {len(chunks)}:")
        text = chunk
        result = llm(prompt.format(text=text))
        print(result)        
        entities_and_relations = result
        elements.append(entities_and_relations)
        
    return elements

# %%
# 3. Element Instances → Element Summaries
def summarize_elements(elements):
    summaries = []
    template = """
    <s>[INST] <<SYS>>
    Summarize the following entities and relationships in a structured format. Use \"->\" to represent relationships, after the \"Relationships:\" word.
    <</SYS>>

    {text} [/INST]
    """


    prompt = PromptTemplate(
        input_variables=["text"],
        template=template,
    )
        
    for index, element in enumerate(elements):
        print(f"Element index {index} of {len(elements)}:")
        text = element
        result = llm(prompt.format(text=text))
        summary = result
        print("Element Summary:", result)
        summaries.append(summary)
    return summaries

# %%
# 4. Element Summaries → Graph Communities
def build_graph_from_summaries(summaries):
    G = nx.Graph()
    for index, summary in enumerate(summaries):
        print(f"Summary index {index} of {len(summaries)}:")
        lines = summary.split("\n")
        entities_section = False
        relationships_section = False
        entities = []
        for line in lines:
            if line.startswith("### Entities:") or line.startswith("**Entities:**"):
                entities_section = True
                relationships_section = False
                continue
            elif line.startswith("### Relationships:") or line.startswith("**Relationships:**"):
                entities_section = False
                relationships_section = True
                continue
            if entities_section and line.strip():
                if line[0].isdigit() and line[1] == ".":
                    line = line.split(".", 1)[1].strip()
                entity = line.strip()
                entity = entity.replace("**", "")
                entities.append(entity)
                G.add_node(entity)
            elif relationships_section and line.strip():
                parts = line.split("->")
                if len(parts) >= 2:
                    source = parts[0].strip()
                    target = parts[-1].strip()
                    relation = " -> ".join(parts[1:-1]).strip()
                    G.add_edge(source, target, label=relation)
    return G

# %%
# 5. Graph Communities → Community Summaries
def detect_communities(graph):
    communities = []
    index = 0
    for component in nx.connected_components(graph):
        print(
            f"Component index {index} of {len(list(nx.connected_components(graph)))}:")
        subgraph = graph.subgraph(component)
        if len(subgraph.nodes) > 1:  # Leiden algorithm requires at least 2 nodes
            try:
                sub_communities = algorithms.leiden(subgraph)
                for community in sub_communities.communities:
                    communities.append(list(community))
            except Exception as e:
                print(f"Error processing community {index}: {e}")
        else:
            communities.append(list(subgraph.nodes))
        index += 1
    print("Communities from detect_communities:", communities)
    return communities


def summarize_communities(communities, graph):
    community_summaries = []
    template = """
    <s>[INST] <<SYS>>
    Summarize the following community of entities and relationships.
    <</SYS>>

    {text} [/INST]
    """


    prompt = PromptTemplate(
        input_variables=["text"],
        template=template,
    )
        
    for index, community in enumerate(communities):
        print(f"Summarize Community index {index} of {len(communities)}:")
        subgraph = graph.subgraph(community)
        nodes = list(subgraph.nodes)
        edges = list(subgraph.edges(data=True))
        description = "Entities: " + ", ".join(nodes) + "\nRelationships: "
        relationships = []
        for edge in edges:
            relationships.append(
                f"{edge[0]} -> {edge[2]['label']} -> {edge[1]}")
        description += ", ".join(relationships)
        text = description
        result = llm(prompt.format(text=text))
        summary = result.strip()
        print("Community Summary: ", summary)
        community_summaries.append(summary)
        
    return community_summaries

# %%
# 6. Community Summaries → Community Answers → Global Answer
def generate_answers_from_communities(community_summaries, query):
    intermediate_answers = []
    template = """
    <s>[INST] <<SYS>>
    Answer the following query based on the provided summary.
    <</SYS>>

    {text} [/INST]
    """


    prompt = PromptTemplate(
        input_variables=["text"],
        template=template,
    )   
        
    for index, summary in enumerate(community_summaries):
        print(f"Summary index {index} of {len(community_summaries)}:")
        text = summary
        result = llm(prompt.format(text=text))
        
    
        print("Intermediate answer:", result)
        intermediate_answers.append(result)
    template = """
    <s>[INST] <<SYS>>
    Combine these answers into a final, concise response.
    <</SYS>>

    {text} [/INST]
    """


    prompt = PromptTemplate(
        input_variables=["text"],
        template=template,
    )

    text = intermediate_answers
    result = llm(prompt.format(text=text))
    final_answer = result
    return final_answer

# %%
# Putting It All Together
def graph_rag_pipeline(documents, query, chunk_size=600, overlap_size=100):
    chunks = split_documents_into_chunks(documents, chunk_size, overlap_size)
    elements = extract_elements_from_chunks(chunks)
    summaries = summarize_elements(elements)
    graph = build_graph_from_summaries(summaries)
    print("graph:", graph)
    communities = detect_communities(graph)
    print("communities:", communities[0])
    community_summaries = summarize_communities(communities, graph)
    final_answer = generate_answers_from_communities(
        community_summaries, query)
    return final_answer

# %% [markdown]
# #### PDF Parsing using LLama Index

# %%
# !pip3 install llama-index
# Out:
# Collecting llama-index
#   Downloading llama_index-0.11.14-py3-none-any.whl.metadata (11 kB)
# Collecting llama-index-agent-openai<0.4.0,>=0.3.4 (from llama-index)
#   Downloading llama_index_agent_openai-0.3.4-py3-none-any.whl.metadata (728 bytes)
# Collecting llama-index-cli<0.4.0,>=0.3.1 (from llama-index)
#   Downloading llama_index_cli-0.3.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting llama-index-core<0.12.0,>=0.11.14 (from llama-index)
#   Downloading llama_index_core-0.11.14-py3-none-any.whl.metadata (2.4 kB)
# Collecting llama-index-embeddings-openai<0.3.0,>=0.2.4 (from llama-index)
#   Downloading llama_index_embeddings_openai-0.2.5-py3-none-any.whl.metadata (686 bytes)
# Collecting llama-index-indices-managed-llama-cloud>=0.3.0 (from llama-index)
#   Downloading llama_index_indices_managed_llama_cloud-0.4.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting llama-index-legacy<0.10.0,>=0.9.48 (from llama-index)
#   Downloading llama_index_legacy-0.9.48.post3-py3-none-any.whl.metadata (8.5 kB)
# Collecting llama-index-llms-openai<0.3.0,>=0.2.9 (from llama-index)
#   Downloading llama_index_llms_openai-0.2.9-py3-none-any.whl.metadata (648 bytes)
# Collecting llama-index-multi-modal-llms-openai<0.3.0,>=0.2.0 (from llama-index)
#   Downloading llama_index_multi_modal_llms_openai-0.2.1-py3-none-any.whl.metadata (728 bytes)
# Collecting llama-index-program-openai<0.3.0,>=0.2.0 (from llama-index)
#   Downloading llama_index_program_openai-0.2.0-py3-none-any.whl.metadata (766 bytes)
# Collecting llama-index-question-gen-openai<0.3.0,>=0.2.0 (from llama-index)
#   Downloading llama_index_question_gen_openai-0.2.0-py3-none-any.whl.metadata (785 bytes)
# Collecting llama-index-readers-file<0.3.0,>=0.2.0 (from llama-index)
#   Downloading llama_index_readers_file-0.2.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting llama-index-readers-llama-parse>=0.3.0 (from llama-index)
#   Downloading llama_index_readers_llama_parse-0.3.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting nltk>3.8.1 (from llama-index)
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting openai>=1.14.0 (from llama-index-agent-openai<0.4.0,>=0.3.4->llama-index)
#   Downloading openai-1.50.2-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: PyYAML>=6.0.1 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /opt/conda/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.14->llama-index) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (3.9.5)
# Requirement already satisfied: dataclasses-json in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (1.2.14)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (2024.6.1)
# Requirement already satisfied: httpx in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (3.3)
# Requirement already satisfied: numpy<2.0.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (10.3.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (8.3.0)
# Collecting tiktoken>=0.3.3 (from llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (1.16.0)
# Collecting llama-cloud>=0.0.11 (from llama-index-indices-managed-llama-cloud>=0.3.0->llama-index)
#   Downloading llama_cloud-0.1.0-py3-none-any.whl.metadata (750 bytes)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.2.2)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /opt/conda/lib/python3.10/site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (4.12.3)
# Collecting pypdf<5.0.0,>=4.0.1 (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index)
#   Downloading pypdf-4.3.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index)
#   Downloading striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Collecting llama-parse>=0.5.0 (from llama-index-readers-llama-parse>=0.3.0->llama-index)
#   Downloading llama_parse-0.5.6-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk>3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk>3.8.1->llama-index) (2024.5.15)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.14->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.14->llama-index) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.14->llama-index) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.14->llama-index) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.14->llama-index) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.14->llama-index) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (2.5)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.14->llama-index) (4.4.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.14->llama-index) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.14->llama-index) (1.0.5)
# Requirement already satisfied: idna in /opt/conda/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.14->llama-index) (3.7)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.14->llama-index) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.14->llama-index) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama-index) (1.9.0)
# Collecting jiter<1,>=0.4.0 (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama-index)
#   Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.14->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/conda/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.14->llama-index) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.14->llama-index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.14->llama-index) (1.26.18)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.14->llama-index) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.14->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.14->llama-index) (3.22.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2024.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio->httpx->llama-index-core<0.12.0,>=0.11.14->llama-index) (1.2.0)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.14->llama-index) (24.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (1.16.0)
# Downloading llama_index-0.11.14-py3-none-any.whl (6.8 kB)
# Downloading llama_index_agent_openai-0.3.4-py3-none-any.whl (13 kB)
# Downloading llama_index_cli-0.3.1-py3-none-any.whl (27 kB)
# Downloading llama_index_core-0.11.14-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 27.8 MB/s eta 0:00:00a 0:00:01
# Downloading llama_index_embeddings_openai-0.2.5-py3-none-any.whl (6.1 kB)
# Downloading llama_index_indices_managed_llama_cloud-0.4.0-py3-none-any.whl (10 kB)
# Downloading llama_index_legacy-0.9.48.post3-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 53.0 MB/s eta 0:00:00
# Downloading llama_index_llms_openai-0.2.9-py3-none-any.whl (12 kB)
# Downloading llama_index_multi_modal_llms_openai-0.2.1-py3-none-any.whl (5.9 kB)
# Downloading llama_index_program_openai-0.2.0-py3-none-any.whl (5.3 kB)
# Downloading llama_index_question_gen_openai-0.2.0-py3-none-any.whl (2.9 kB)
# Downloading llama_index_readers_file-0.2.2-py3-none-any.whl (38 kB)
# Downloading llama_index_readers_llama_parse-0.3.0-py3-none-any.whl (2.5 kB)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 57.8 MB/s eta 0:00:00
# Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Downloading llama_cloud-0.1.0-py3-none-any.whl (176 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.3/176.3 kB 11.6 MB/s eta 0:00:00
# Downloading llama_parse-0.5.6-py3-none-any.whl (10 kB)
# Downloading openai-1.50.2-py3-none-any.whl (382 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.0/383.0 kB 24.2 MB/s eta 0:00:00
# Downloading pypdf-4.3.1-py3-none-any.whl (295 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.8/295.8 kB 18.5 MB/s eta 0:00:00
# Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 48.1 MB/s eta 0:00:00
# Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 20.7 MB/s eta 0:00:00
# Installing collected packages: striprtf, dirtyjson, pypdf, nltk, jiter, tiktoken, openai, llama-index-core, llama-cloud, llama-parse, llama-index-readers-file, llama-index-llms-openai, llama-index-legacy, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-index-readers-llama-parse, llama-index-multi-modal-llms-openai, llama-index-cli, llama-index-agent-openai, llama-index-program-openai, llama-index-question-gen-openai, llama-index
#   Attempting uninstall: pypdf
#     Found existing installation: pypdf 5.0.0
#     Uninstalling pypdf-5.0.0:
#       Successfully uninstalled pypdf-5.0.0
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.2.4
#     Uninstalling nltk-3.2.4:
#       Successfully uninstalled nltk-3.2.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# preprocessing 0.1.13 requires nltk==3.2.4, but you have nltk 3.9.1 which is incompatible.
# Successfully installed dirtyjson-1.0.8 jiter-0.5.0 llama-cloud-0.1.0 llama-index-0.11.14 llama-index-agent-openai-0.3.4 llama-index-cli-0.3.1 llama-index-core-0.11.14 llama-index-embeddings-openai-0.2.5 llama-index-indices-managed-llama-cloud-0.4.0 llama-index-legacy-0.9.48.post3 llama-index-llms-openai-0.2.9 llama-index-multi-modal-llms-openai-0.2.1 llama-index-program-openai-0.2.0 llama-index-question-gen-openai-0.2.0 llama-index-readers-file-0.2.2 llama-index-readers-llama-parse-0.3.0 llama-parse-0.5.6 nltk-3.9.1 openai-1.50.2 pypdf-4.3.1 striprtf-0.0.26 tiktoken-0.7.0

# %%
from llama_index.core import VectorStoreIndex
import nest_asyncio
nest_asyncio.apply()
from llama_parse import LlamaParse
from llama_index.core import SimpleDirectoryReader
import os
parser = LlamaParse(api_key="",)                # API Key hidden

# %%
# Documents Pre-Processing
async def read_documents_from_files():
    documents = []
    for filename in sorted(os.listdir('/kaggle/input/dataset')):
        document = await parser.aload_data(f'/kaggle/input/dataset/{filename}')
        documents.append(document[0].text)
    return documents

async def collect_documents():
    DOCUMENTS = await read_documents_from_files()
    return DOCUMENTS

DOCUMENTS = await collect_documents()
# Out:
# Started parsing the file under job_id 4658e5cf-9543-4575-8883-fec2fa43798e
# Started parsing the file under job_id 09b63242-6a14-4dbf-a9a9-dd8e4c492430
# Started parsing the file under job_id 82681649-4291-4aaa-a5f7-9a42b5ba828a
# Started parsing the file under job_id 4dfa3a52-defd-4ad7-8b81-ec24d8ac803d
# ..Started parsing the file under job_id 3908e6a7-9694-4d48-a1ea-8607b7a6fcd2
# .Started parsing the file under job_id 07431434-2df4-4560-baa5-c429a7b3869e
# .Started parsing the file under job_id 3cecea24-f7d6-41c7-89d6-a94bd8491b7a
# .Started parsing the file under job_id 4b8b344e-c15d-4ca4-8731-c3ed152e1c1f
# .Started parsing the file under job_id f4366ea4-d0bc-4c21-8cf3-a6f3ac647a49
# .Started parsing the file under job_id fb3c0ee2-d54d-4f5e-bbd0-4f819525c3a6
# .Started parsing the file under job_id 3fd06488-5835-48b8-b352-6e254f7ea8c5
# .Started parsing the file under job_id bcfe3abc-0667-4557-b055-28a7b3d73d76
# ..Started parsing the file under job_id ca14a7c7-2aae-486a-aa10-99e29b78ca7a
# ...Started parsing the file under job_id 6653d8c8-151f-41a3-bf54-3a3c52fbdbf1
# ..Started parsing the file under job_id 844ef126-5100-4a53-b345-1e9af97bbb0e
# .Started parsing the file under job_id 7dd43f6d-32a4-4b95-bc4e-3cc0a93a7723
# .Started parsing the file under job_id 7e7abdca-fea5-49bc-a056-f42eb09dfa52
# .Started parsing the file under job_id 2ec7744f-1323-4e10-92f3-2ae861d7278d
# ..Started parsing the file under job_id 808e0c1f-5c17-4f4b-aa77-f3581a25021b
# .Started parsing the file under job_id d6a71a26-916b-4cd9-a461-b9fb5ad3fedb

# %%
import json
doc_dict = {f"Document {i+1}": doc for i, doc in enumerate(DOCUMENTS)}
with open('Save_dataset_documents.json', 'w') as file:
    json.dump(doc_dict, file)

# %%
query = "What are the main themes in these documents?"
print('Query:', query)
answer = graph_rag_pipeline(DOCUMENTS, query)
print('Answer:', answer)
# Out:
# Query: What are the main themes in these documents?
# Chunk index 0 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                                                                                           UNITED STATES
#                                                           SECURITIES AND EXCHANGE COMMISSIONWashington, D.C. 20549
#
#                                                                                        FORM 10-Q
# (Mark One)
#                           ☒ QUARTERLY REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934
#                                                                          For the quarterly period ended June 25, 2022
#                                            [/INST]
#      Entities:
#         • United States
#         • Securities and Exchange Commission (SEC)
#
# Relationships:
#
# • The text mentions the location of the Securities and Exchange Commission in Washington, D.C. This establishes a spatial relationship between the two entities.
# Chunk index 1 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                  For the quarterly period ended June 25, 2022
#                                                                                                     or
#                           ☐ TRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934
#                                                                        For the transition period from                  to           .
#                                                                               Commission File Number: 001-36743
#
#                                                                             [/INST]
#      Here are the entities and relationships that can be extracted from the given text:
#
# Entities:
#
# 1. Company: The entity that is filing the report is a company with a Commission File Number of 001-36743.
# 2. Quarterly period: The text refers to a quarterly period ended on June 25, 2022.
# 3. Transition report: The text states that the document is a transition report pursuant to Section 13 or 15(d) of the Securities Exchange Act of 1934.
#
# Relationships:
#
# 1. Filing relationship: The company is filing a report with the Securities and Exchange Commission (SEC).
# 2. Time relationship: The quarterly period ended on June 25, 2022, is related to the transition period from to.
# Chunk index 2 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#      File Number: 001-36743
#
#                                                                                        Apple Inc.
#                                                                      (Exact name of Registrant as specified in its charter)
#
#                                        California                                                                                                     94-2404110
#                                (State or other jurisdiction                                                                               (I.R.S. Employer Identification No.)
#                  [/INST]
#      Entities:
#         • Apple Inc. (Registrant)
#
# Relationships:
#
# • Apple Inc. is the registrant, and the entity that is incorporated in California.
# Chunk index 3 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                                                    (I.R.S. Employer Identification No.)
#                            of incorporation or organization)
#
#                                One Apple Park Way
#                                Cupertino, California                                                                                                      95014
#                         (Address of principal executive offices)                                                                                        (Zip Code)
#
#                                                                                  [/INST]
#      Entities:
#
# 1. IRS (Internal Revenue Service)
# 2. Apple Inc.
# 3. One Apple Park Way (address)
# 4. Cupertino, California (city)
# 5. California (state)
# 6. Zip Code (95014)
#
# Relationships:
#
# 1. IRS is the entity that issues Employer Identification Numbers (EINs).
# 2. Apple Inc. is the entity that has been issued an EIN by the IRS.
# 3. One Apple Park Way is the address of Apple Inc.'s principal executive offices.
# 4. Cupertino, California is the city where Apple Inc.'s principal executive offices are located.
# 5. California is the state where Apple Inc. is incorporated.
# 6. Zip Code 95014 is the postal code for Cupertino, California.
# Chunk index 4 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#             (Zip Code)
#
#                                                                                             (408) 996-1010
#                                                                         (Registrant’s telephone number, including area code)
#
#                                                                      Securities registered pursuant to Section 12(b) of the Act:
#                                   Title of each class                                       Trading symbol(s)                      Name of each exchange on which registered
#              Common Stock, $0.00001 par value [/INST]
#      Sure! Here are the entities and relationships extracted from the text:
#
# Entities:
#
# * Zip Code: (408) 996-1010
# * Registrant's Telephone Number: (408) 996-1010
# * Securities Registered:
# 	+ Common Stock, $0.00001 par value
#
# Relationships:
#
# * The registrant's telephone number is included in the zip code.
# * The common stock is registered pursuant to Section 12(b) of the Act.
# Chunk index 5 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                  Name of each exchange on which registered
#              Common Stock, $0.00001 par value per share                                          AAPL                                   The Nasdaq Stock Market LLC
#                               1.000% Notes due 2022                                                —                                    The Nasdaq Stock Market LLC
#                               1.375% Notes due 2024                                                —                                    The Nasdaq Stock Market LLC
#                               0.000% Notes due 2025   [/INST]
#      Sure! Here are the entities and relationships extracted from the text:
#
# Entities:
#
# * Apple Inc. (AAPL)
# * The Nasdaq Stock Market LLC
#
# Relationships:
#
# * Apple Inc. is listed on The Nasdaq Stock Market LLC.
#
# Note that there are no explicit relationships mentioned in the text between Apple Inc. and the notes with different maturity dates. However, based on the context, it can be inferred that Apple Inc. issued these notes and they are listed on The Nasdaq Stock Market LLC.
# Chunk index 6 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                        The Nasdaq Stock Market LLC
#                               0.000% Notes due 2025                                                —                                    The Nasdaq Stock Market LLC
#                               0.875% Notes due 2025                                                —                                    The Nasdaq Stock Market LLC
#                               1.625% Notes due 2026                                                —                                    The Nasdaq Stock Market LLC
#                               2.000% Notes due 2027           [/INST]
#      Sure! Here are the entities and relationships that can be extracted from the given text:
#
# Entities:
#
# 1. The Nasdaq Stock Market LLC (issuer)
#
# Relationships:
#
# 1. Issuer-Note: Each note (0.000%, 0.875%, 1.625%, 2.000%) is issued by The Nasdaq Stock Market LLC.
# Chunk index 7 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                The Nasdaq Stock Market LLC
#                               2.000% Notes due 2027                                                —                                    The Nasdaq Stock Market LLC
#                               1.375% Notes due 2029                                                —                                    The Nasdaq Stock Market LLC
#                               3.050% Notes due 2029                                                —                                    The Nasdaq Stock Market LLC
#                               0.500% Notes due 2031                   [/INST]
#      Sure! Here are the entities and relationships that can be extracted from the given text:
#
# Entities:
#
# 1. The Nasdaq Stock Market LLC (issuer)
#
# Relationships:
#
# 1. Issuer of the notes (The Nasdaq Stock Market LLC)
# 2. Type of notes (2.000%, 1.375%, 3.050%, 0.500%)
# 3. Maturity year (2027, 2029, 2029, 2031)
# Chunk index 8 of 211:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#        The Nasdaq Stock Market LLC
#                               0.500% Notes due 2031                                                —                                    The Nasdaq Stock Market LLC
#                               3.600% Notes due 2042                                                —                                    The Nasdaq Stock Market LLC
#
# Indicate by check mark whether the Registrant (1) has filed all reports required to be filed by Section 13 or 15(d) of the Securities Exchange Act of 1934 during the preceding 12
# months (or for such shorter period that the Registrant was re [/INST]
#      Sure! Here are the entities and relationships I extracted from the text:
#
# Entities:
#
# 1. The Nasdaq Stock Market LLC
#
# Relationships:
#
# 1. The Nasdaq Stock Market LLC is the issuer of the notes.
# Chunk index 9 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#     ge Act of 1934 during the preceding 12
# months (or for such shorter period that the Registrant was required to file such reports), and (2) has been subject to such filing requirements for the past 90 days.
#                                                                                             Yes ☒       No ☐
#
# Indicate by check mark whether the Registrant has submitted electronically every Interactive Data File required to be submitted pursuant to Rule 405 of Regulation S-T (§232.405 of
# this chapter) during the preceding 12 months (or for such shorter period that the Registrant was required [/INST]
#      Sure! Here are the entities and relationships I found in the text:
#
# Entities:
#
# * Registrant (the company or organization that is filing the document)
#
# Relationships:
#
# * The Registrant has submitted interactive data files pursuant to Rule 405 of Regulation S-T.
#
# Note that there are no other entities or relationships mentioned in the text.
# Chunk index 10 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#     chapter) during the preceding 12 months (or for such shorter period that the Registrant was required to submit such files).
#                                                                                             Yes ☒       No ☐
# Indicate by check mark whether the Registrant is a large accelerated filer, an accelerated filer, a non-accelerated filer, a smaller reporting company, or an emerging growth company.
# See the definitions of “large accelerated filer,” “accelerated filer,” “smaller reporting company,” and “emerging growth company” in Rule 12b-2 of the Exchange Act.
#
# Large accelerated  [/INST]
#      Sure! Here are the entities and relationships I found in the text:
#
# Entities:
#
# * Registrant (the company being described)
#
# Relationships:
#
# * The Registrant has submitted certain filings (not specified) during the past 12 months (or a shorter period).
# * The Registrant is required to submit these filings.
# Chunk index 11 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#     rting company,” and “emerging growth company” in Rule 12b-2 of the Exchange Act.
#
# Large accelerated filer                     ☒                                                                                                     Accelerated filer                     ☐
# Non-accelerated filer                       ☐                                                                                                     Smaller reporting company             ☐
#                                                                                                                                                    [/INST]
#      Sure! Here are the entities and relationships extracted from the text:
#
# Entities:
#
# * Company
# * Exchange Act
# * Rule 12b-2
#
# Relationships:
#
# * Large accelerated filer (entity) is related to:
# 	+ Accelerated filer (entity)
# 	+ Non-accelerated filer (entity)
# 	+ Smaller reporting company (entity)
#
# Note that the entities and relationships listed above are based on the terms used in the text and do not necessarily reflect real-world entities or relationships.
# Chunk index 12 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                                                                                                         Emerging growth company               ☐ [/INST]
#      Entities:
#
# * Emerging growth company (EGC)
# Chunk index 13 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#     Table of Contents
#
#                                                                               UNITED STATES
#                                         SECURITIES AND EXCHANGE COMMISSIONWashington, D.C. 20549
#                                                                          ____________________________________
#                                                                                      FORM 10-Q
#                                                                         ____________________________________
# (Mark One)
# ☒           QUARTERLY REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE [/INST]
#      Sure! Here are the entities and relationships I found in the text:
#
# Entities:
#
# 1. United States
# 2. Securities and Exchange Commission (SEC)
# 3. Form 10-Q
#
# Relationships:
#
# 1. The text is located in Washington, D.C., which is a part of the United States.
# 2. The Securities and Exchange Commission (SEC) is a government agency that is responsible for regulating the securities market in the United States.
# 3. Form 10-Q is a financial report that publicly traded companies are required to file with the SEC on a quarterly basis.
# Chunk index 14 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#     _____________________
# (Mark One)
# ☒           QUARTERLY REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF
#             1934
#                                                                   For the quarterly period ended September 30, 2022
#                                                                                                    or
# ☐           TRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF
#             1934
#                                                                      For the transition period from                    to    [/INST]
#      Entities:
#         • Mark One (the company filing the report)
#
# Relationships:
#
# • The company is filing a Quarterly Report pursuant to Section 13 or 15(d) of the Securities Exchange Act of 1934.
#
# • The report covers the quarterly period ended September 30, 2022.
#
# • The report is also a Transition Report pursuant to Section 13 or 15(d) of the Securities Exchange Act of 1934.
#
# • The transition period covered in the report is from [insert date range].
# Chunk index 15 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                                                  For the transition period from                    to           .
#                                                                                Commission File No. 000-22513
#                                                                         ____________________________________
#
#                                                                AMAZON.COM, INC.
#                                                                   (Exact name of registrant as specified in its charter)
#                                                                        [/INST]
#      Entities:
#
# * AMAZON.COM, INC. (registered company name)
#
# Relationships:
#
# * None identified in the given text.
# Chunk index 16 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#      as specified in its charter)
#                                                                          ____________________________________
#                                           Delaware                                                                                               91-1646860
#                                  (State or other jurisdiction of                                                                               (I.R.S. Employer
#                                 incorporation or organization)                                                                                Id [/INST]
#      Sure! Here are the entities and relationships extracted from the given text:
#
# Entities:
#
# 1. Delaware (state)
# 2. 91-1646860 (IRS employer ID)
#
# Relationships:
#
# 1. Delaware is the state of incorporation or organization.
# 2. 91-1646860 is the IRS employer ID assigned to Delaware.
# Chunk index 17 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#     n or organization)                                                                                Identification No.)
#
#                                                                   410 Terry Avenue North, Seattle, Washington 98109-5210
#                                                                                             (206) 266-1000
#                                                   (Address and telephone number, including area code, of registrant’s principal executive offices)
#
#                                                                       Securities registered pursuant to S [/INST]
#      Sure! Here are the entities and relationships that can be extracted from the given text:
#
# Entities:
#
# 1. Company (not explicitly mentioned but can be inferred as the entity registering the securities)
# 2. Registrant (the company or organization registering the securities)
# 3. Principal Executive Offices (the location where the registrant's top executives are based)
#
# Relationships:
#
# 1. The company is the registrant of the securities.
# 2. The principal executive offices are located at 410 Terry Avenue North, Seattle, Washington 98109-5210.
# 3. The company has a phone number (206) 266-1000.
# Chunk index 18 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                                                                      Securities registered pursuant to Section 12(b) of the Act:
#                                 Title of Each Class                                          Trading Symbol(s)                               Name of Each Exchange on Which Registered
#                     Common Stock, par value $.01 per share                                        AMZN                                             Nasdaq Global Select Market
#                                                                            ____________________________________
#       [/INST]
#      Entities:
#
# 1. Amazon (AMZN)
#
# Relationships:
#
# 1. Amazon is registered on the Nasdaq Global Select Market under the trading symbol "AMZN".
# Chunk index 19 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                                                               ____________________________________
#         Indicate by check mark whether the registrant (1) has filed all reports required to be filed by Section 13 or 15(d) of the Securities Exchange Act of 1934 during the
# preceding 12 months (or for such shorter period that the registrant was required to file such reports), and (2) has been subject to such filing requirements for the past
# 90 days.    Yes ☒      No ☐
#
#         Indicate by check mark whether the registrant has submitted electronically every Interactive Data File required to be submit [/INST]
#      Sure! Here are the entities and relationships I found in the text:
#
# Entities:
#
# * Registrant (the company or organization that is filling out the form)
#
# Relationships:
#
# * The registrant has filed reports (there is a relationship between the registrant and the reports they have filed)
# * The registrant has been subject to filing requirements (there is a relationship between the registrant and the filing requirements they have been subject to)
# Chunk index 20 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#     hether the registrant has submitted electronically every Interactive Data File required to be submitted pursuant to Rule 405 of Regulation S-T
# during the preceding 12 months (or for such shorter period that the registrant was required to submit such files).               Yes ☒      No ☐
#
#         Indicate by check mark whether the registrant is a large accelerated filer, an accelerated filer, a non-accelerated filer, a smaller reporting company, or an emerging growth
# company. See the definitions of “large accelerated filer,” “accelerated filer,” “smaller reporting company,” and “emerging growth [/INST]
#      Sure! Here are the entities and relationships extracted from the given text:
#
# Entities:
#
# * Registrant
# * Company
#
# Relationships:
#
# * The registrant submits Interactive Data Files to the SEC.
# * The registrant is required to submit these files pursuant to Rule 405 of Regulation S-T.
# Chunk index 21 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#     of “large accelerated filer,” “accelerated filer,” “smaller reporting company,” and “emerging growth company” in Rule 12b-2 of the Exchange Act.
# Large accelerated filer                    ☒                                                                                          Accelerated filer                                ☐
# Non-accelerated filer                      ☐                                                                                          Smaller reporting company                        ☐
#                                                                                       [/INST]
#      Entities:
#         • Rule 12b-2
#         • Exchange Act
#      Relationships:
#         • Large accelerated filer
#         • Accelerated filer
#         • Smaller reporting company
#         • Emerging growth company
# Chunk index 22 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                  ☐
#                                                                                                                                       Emerging growth company                          ☐
#         If an emerging growth company, indicate by check mark if the registrant has elected not to use the extended transition period for complying with any new or revised
# financial accounting standards provided pursuant to Section 13(a) of the Exchange Act.               ☐
#         Indicate by check mark whether the registrant is a shell company (as defined in Rule 12b-2 of the Exchange Act).      [/INST]
#      Sure! Here are the entities and relationships that can be extracted from the given text:
#
# Entities:
#
# * Registrant
# * Company
#
# Relationships:
#
# * The registrant has elected not to use the extended transition period for complying with any new or revised financial accounting standards.
# * The registrant is subject to the reporting requirements of the Securities Exchange Act of 1934.
# Chunk index 23 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#      mark whether the registrant is a shell company (as defined in Rule 12b-2 of the Exchange Act).                   Yes ☐      No ☒
#         10,201,654,176 shares of common stock, par value $0.01 per share, outstanding as of October 19, 2022 [/INST]
#      Sure! Here are the entities and relationships extracted from the text:
#
# Entities:
#
# * Company (referred to as "registrant")
# * Shareholder (not explicitly mentioned but implied by the mention of "common stock" and "outstanding shares")
#
# Relationships:
#
# * The registrant has outstanding shares of common stock (owned by shareholders)
# Chunk index 24 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                                                       UNITED STATES SECURITIES AND EXCHANGE COMMISSIONWashington, D.C. 20549
#
#                                                                                                    FORM 10-Q
# (Mark One)
#
#      ☑      QUARTERLY REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934
#             For the quarterly period ended                           October 1, 2022
#                                                                                                                  or
#      ☐      TRANSITION REPORT PURSUANT TO SECTION 13 OR  [/INST]
#      Sure! Here are the entities and relationships I found in the text:
#
# Entities:
#
# 1. United States Securities and Exchange Commission (SEC)
# 2. Washington, D.C.
#
# Relationships:
#
# 1. The text is a form submitted to the SEC, which is headquartered in Washington, D.C.
# Chunk index 25 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                                              or
#      ☐      TRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934
#             For the transition period from                     to
#                                                                                            Commission File Number 000-06217Intel
#                                                                                   (Exact name of registrant as specified in its charter)
#                                                                                                                             [/INST]
#      Entities:
#         • Intel
#
#      Relationships:
#         • None
# Chunk index 26 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                                                                                                                      INTEL CORPORATION
#                                                                        Delaware                                                                                                     94-1672743
#                                            (State or other jurisdiction of incorporation or organization)                                                              (I.R.S. Employer Identification No.)
#                   2200 Mission College Boulevard,                          [/INST]
#      Sure! Here are the entities and relationships that can be extracted from the given text:
#
# Entities:
#
# 1. INTEL CORPORATION - This is the name of the company.
# 2. Delaware - This is the state where the company was incorporated.
# 3. IRS Employer Identification Number - This is the unique identification number assigned to the company by the Internal Revenue Service.
#
# Relationships:
#
# 1. INTEL CORPORATION is incorporated in Delaware.
# 2. The IRS Employer Identification Number is associated with INTEL CORPORATION.
# Chunk index 27 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#     loyer Identification No.)
#                   2200 Mission College Boulevard,                                       Santa Clara,                               California                                       95054-1549
#                                                        (Address of principal executive offices)                                                                                      (Zip Code)
#
#                                                                                                          (408) 765-8080
#                                                                        [/INST]
#      Entities:
#
# * Loyer (no specific entity type identified)
#
# Relationships:
#
# * Address (of principal executive offices): 2200 Mission College Boulevard, Santa Clara, California, 95054-1549
# * Zip Code: 95054-1549
# * Phone Number: (408) 765-8080
# Chunk index 28 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                    (408) 765-8080
#                                                                                   (Registrant’s telephone number, including area code)
#                                                                                                                 N/A
#                                                                (Former name, former address and former fiscal year, if changed since last report)
#
# Securities registered pursuant to Section 12(b) of the Act:
#                          Title of each class                                           Trading Symbol(s)         [/INST]
#      Sure! Here are the entities and relationships extracted from the text:
#
# Entities:
#
# * Registrant (the company or organization registering the securities)
# * Telephone number (a contact method for the registrant)
#
# Relationships:
#
# * The registrant's telephone number is associated with the registrant.
# Chunk index 29 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                  Title of each class                                           Trading Symbol(s)                                             Name of each exchange on which registered
#                Common stock, $0.001 par value                                                  INTC                                                            Nasdaq Global Select Market
# Indicate by check mark whether the registrant (1) has filed all reports required to be filed by Section 13 or 15(d) of the Securities Exchange Act of 1934 during the preceding 12 months
# (or for such shorter period that the registrant  [/INST]
#      Sure! Here are the entities and relationships I found in the given text:
#
# Entities:
#
# 1. Intel Corporation (INTC)
# 2. Nasdaq Global Select Market
# 3. Securities Exchange Act of 1934
#
# Relationships:
#
# 1. Intel Corporation is listed on the Nasdaq Global Select Market.
# 2. The Securities Exchange Act of 1934 requires Intel Corporation to file reports.
#
# Note that there are no explicit relationships between the entities mentioned other than the listing of Intel Corporation on the Nasdaq Global Select Market.
# Chunk index 30 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#     Exchange Act of 1934 during the preceding 12 months
# (or for such shorter period that the registrant was required to file such reports), and (2) has been subject to such filing requirements for the past 90 days. Yes ☑                                    No ¨
# Indicate by check mark whether the registrant has submitted electronically every Interactive Data File required to be submitted pursuant to Rule 405 of Regulation S-T (§232.405 of this
# chapter) during the preceding 12 months (or for such shorter period that the registrant was required to submit such files). Yes ☑                              [/INST]
#      Entities:
#         • Registrant
#      Relationships:
#         • None
# Chunk index 31 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#     er period that the registrant was required to submit such files). Yes ☑                                 No ¨
# Indicate by check mark whether the registrant is a large accelerated filer, an accelerated filer, a non-accelerated filer, a smaller reporting company, or an emerging growth company. See
# the definitions of “large accelerated filer,” “accelerated filer,” “smaller reporting company,” and "emerging growth company" in Rule 12b-2 of the Exchange Act.
#       Large Accelerated Filer                 Accelerated filer                          Non-accelerated filer                            Small [/INST]
#      Sure! Here are the entities and relationships extracted from the text:
#
# Entities:
#
# * Registrant (the entity that is required to submit financial statements)
#
# Relationships:
#
# * The registrant is required to submit financial statements (obligation)
#
# Note that there are no other entities or relationships mentioned in the text.
# Chunk index 32 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#        Accelerated filer                          Non-accelerated filer                            Smaller reporting company                        Emerging growth company
#                    ☑                                     ¨                                           ¨                                                     ☐                                                ☐
# If an emerging growth company, indicate by check mark if the registrant has elected not to use the extended transition period for complying with any new or revised financial accounting
# standards provided pursuant to Section 13 [/INST]
#      Entities:
#         - Registrant
#      Relationships:
#         - None (no relationships mentioned in the text)
#
# The text mentions four types of filers:
#
# 1. Accelerated filer
# 2. Non-accelerated filer
# 3. Smaller reporting company
# 4. Emerging growth company
# Chunk index 33 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#     for complying with any new or revised financial accounting
# standards provided pursuant to Section 13(a) of the Exchange Act. ¨
#
# Indicate by check mark whether the registrant is a shell company (as defined in Rule 12b-2 of the Exchange Act).                               Yes ☐      No ☑
# As of October 1, 2022, the registrant had outstanding 4,127 million shares of common stock. [/INST]
#      Sure! Here are the entities and relationships I found in the text:
#
# Entities:
#
# * Registrant
# * Exchange Act
#
# Relationships:
#
# * The registrant must comply with new or revised financial accounting standards pursuant to Section 13(a) of the Exchange Act.
# * The registrant has outstanding shares of common stock.
# Chunk index 34 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                                                                              UNITED STATES
#                                      SECURITIES AND EXCHANGE COMMISSIONWashington, D.C. 20549
#
#                                                                                 FORM 10-Q
# ☒        QUARTERLY REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934
#          For the Quarterly Period Ended September 30, 2022
#                                                                                                  OR
# ☐        TRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURI [/INST]
#      Entities:
#
# 1. United States
# 2. Securities and Exchange Commission (SEC)
#
# Relationships:
#
# 1. The text is a quarterly report submitted by the Securities and Exchange Commission (SEC) to the United States government.
# 2. The SEC is a part of the federal government of the United States.
# Chunk index 35 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                              OR
# ☐        TRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934
#          For the Transition Period From                 to
#                                                                      Commission File Number 001-37845
#
#                                              MICROSOFT CORPORATION
#                                      WASHINGTON                                                                                         91-1144442
#                               (STATE OF INCORPORATION)                                             [/INST]
#      Here are the entities and relationships that can be extracted from the given text:
#
# Entities:
#
# 1. Microsoft Corporation (legal name, location, and state of incorporation)
# 2. Commission (referenced as the filing body for the transition report)
#
# Relationships:
#
# 1. Microsoft Corporation is the filer of the transition report.
# 2. The Commission is the regulatory body that oversees the filing of transition reports.
# Chunk index 36 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#     2
#                               (STATE OF INCORPORATION)                                                                                    (I.R.S. ID)
#                                                          ONE MICROSOFT WAY, REDMOND, WASHINGTON 98052-6399(425) 882-8080
#                                                                              www.microsoft.com/investor
# Securities registered pursuant to Section 12(b) of the Act:
# Title of each class                                                                   Trading Symbol                           Name of exchange on which registered [/INST]
#      Entities:
#         • Microsoft Corporation (STATE OF INCORPORATION)
#             - I.R.S. ID: 425-882-8080
#             - Website: www.microsoft.com/investor
#      Relationships:
#         • None specified in the text.
# Chunk index 37 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                            Trading Symbol                           Name of exchange on which registered
# Common stock, $0.00000625 par value per share                                              MSFT                                                 NASDAQ
# 3.125% Notes due 2028                                                                      MSFT                                                 NASDAQ
# 2.625% Notes due 2033                                                                      MSFT                                                 NASDAQ
# Indicate by check mark whether the registrant  [/INST]
#      Sure! Here are the entities and relationships that can be extracted from the given text:
#
# Entities:
#
# 1. Microsoft Corporation (MSFT)
# 2. NASDAQ
#
# Relationships:
#
# 1. Microsoft Corporation (MSFT) is listed on NASDAQ.
#
# Note that there are no other entities or relationships mentioned in the text.
# Chunk index 38 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                                                    NASDAQ
# Indicate by check mark whether the registrant (1) has filed all reports required to be filed by Section 13 or 15(d) of the Securities Exchange Act of 1934 during the
# preceding 12 months (or for such shorter period that the registrant was required to file such reports), and (2) has been subject to such filing requirements for the past
# 90 days.    Yes ☒      No ☐
# Indicate by check mark whether the registrant has submitted electronically every Interactive Data File required to be submitted pursuant to Rule 405 of Regulation S-T
# (§232.405 of th [/INST]
#      Sure! Here are the entities and relationships I found in the text:
#
# Entities:
#
# * NASDAQ (the registrant)
#
# Relationships:
#
# * The registrant is subject to filing requirements under Section 13 or 15(d) of the Securities Exchange Act of 1934.
# * The registrant has submitted interactive data files pursuant to Rule 405 of Regulation S-T.
# Chunk index 39 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#     nteractive Data File required to be submitted pursuant to Rule 405 of Regulation S-T
# (§232.405 of this chapter) during the preceding 12 months (or for such shorter period that the registrant was required to submit such files).                   Yes ☒      No ☐
# Indicate by check mark whether the registrant is a large accelerated filer, an accelerated filer, a non-accelerated filer, a smaller reporting company, or an emerging
# growth company. See the definitions of “large accelerated filer,” “accelerated filer,” “smaller reporting company,” and “emerging growth company” in Rule 12b-2 of the
# Excha [/INST]
#      Sure! Here are the entities and relationships I found in the text:
#
# Entities:
#
# * Registrant (the company submitting the interactive data file)
# * SEC (Securities and Exchange Commission)
#
# Relationships:
#
# * The registrant is required to submit an interactive data file to the SEC.
# * The SEC has established rules and regulations for the registration of securities, including Rule 405 of Regulation S-T.
# Chunk index 40 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#     erated filer,” “smaller reporting company,” and “emerging growth company” in Rule 12b-2 of the
# Exchange Act.
# Large Accelerated Filer ☒                                                                                                                    Accelerated Filer ☐
# Non-accelerated Filer ☐                                                                                                                      Smaller Reporting Company ☐
#                                                                                                                                              Emerging Growth Comp [/INST]
#      Sure! Here are the entities and relationships extracted from the text:
#
# Entities:
#
# * Large Accelerated Filer
# * Accelerated Filer
# * Non-accelerated Filer
# * Smaller Reporting Company
# * Emerging Growth Company
#
# Relationships:
#
# * These terms (Large Accelerated Filer, Accelerated Filer, Non-accelerated Filer, Smaller Reporting Company, and Emerging Growth Company) are related to companies that file reports with the Securities and Exchange Commission (SEC).
# * The terms define different categories of companies based on their size and other factors, as specified by Rule 12b-2 of the Exchange Act.
# Chunk index 41 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                                                                                     Emerging Growth Company ☐
# If an emerging growth company, indicate by check mark if the registrant has elected not to use the extended transition period for complying with any new or revised
# financial accounting standards provided pursuant to Section 13(a) of the Exchange Act. ☐
# Indicate by check mark whether the registrant is a shell company (as defined in Rule 12b-2 of the Exchange Act).                    Yes ☐     No ☒
# Indicate the number of shares outstanding of each of the issuer’s classes of common stock, as  [/INST]
#      Sure! Here are the entities and relationships I found in the text:
#
# Entities:
#
# * Registrant
# * Issuer
#
# Relationships:
#
# * The registrant is the issuer of common stock.
# Chunk index 42 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#      No ☒
# Indicate the number of shares outstanding of each of the issuer’s classes of common stock, as of the latest practicable date.
# Class                                                                                                                                               Outstanding as of October 20, 2022
# Common Stock, $0.00000625 par value per share                                                                                                                    7,454,473,144 shares [/INST]
#      Sure! Here are the entities and relationships I found in the text:
#
# Entities:
#
# * Issuer (not explicitly mentioned but can be inferred based on the context)
# * Classes of common stock (mentioned explicitly):
# 	+ Common Stock, $0.00000625 par value per share
#
# Relationships:
#
# * Number of shares outstanding (as of October 20, 2022) for each class of common stock
#
# Here's a table summarizing the entities and relationships I found in the text:
#
# | Entity | Relationship |
# | --- | --- |
# | Issuer | Not explicitly mentioned, but can be inferred based on the context |
# | Classes of common stock | - Common Stock, $0.00000625 par value per share |
# | Number of shares outstanding | As of October 20, 2022 |
# Chunk index 43 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                                                                                              UNITED STATES
#                                                                       SECURITIES AND EXCHANGE COMMISSION
#                                                                                     Washington, D.C. 20549
#
#                                                                                         FORM 10-Q
#      ☒      QUARTERLY REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934
#        For the quarterly period ended October 30, 2022
#                                 [/INST]
#      Sure! Here are the entities and relationships that can be extracted from the given text:
#
# Entities:
#
# 1. United States
# 2. Securities and Exchange Commission (SEC)
#
# Relationships:
#
# 1. Location: The SEC is located in Washington, D.C., which is a part of the United States.
# 2. Jurisdiction: The SEC has jurisdiction over the United States.
# Chunk index 44 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#     E ACT OF 1934
#        For the quarterly period ended October 30, 2022
#                                                                                                   OR
#      ☐      TRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934
#                                                                                 Commission file number: 0-23985
#                                                                                           NVIDIA
#                                                                      (Exact name of registrant as specified in its chart [/INST]
#      Sure! Here are the entities and relationships that can be extracted from the given text:
#
# Entities:
#
# 1. NVIDIA (the company)
# 2. Section 13 or 15(d) of the Securities Exchange Act of 1934 (a federal law)
# 3. Commission file number: 0-23985 (a unique identifier for the company's filings with the SEC)
#
# Relationships:
#
# 1. NVIDIA is the registrant (i.e., the company that is filing the report)
# 2. The report is pursuant to Section 13 or 15(d) of the Securities Exchange Act of 1934 (a legal requirement)
# 3. The Commission file number is associated with NVIDIA's filings with the SEC (an identifying number).
# Chunk index 45 of 211:
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                                                      (Exact name of registrant as specified in its charter)NVIDIA CORPORATION
# ...
#
# Entities:
#
# 1. Registrant
# 2. Rule 405 of Regulation S-T
# 3. Interactive Data Files
#
# Relationships:
#
# 1. The registrant is required to file reports with the SEC.
# 2. The registrant must submit interactive data files pursuant to Rule 405 of Regulation S-T.
# 3. The registrant must submit these files on a regular basis (every 12 months or for a shorter period if required).
# Element index 82 of 211:
# Element Summary:
#     <s>[INST] <<SYS>>
#     Summarize the following entities and relationships in a structured format. Use "->" to represent relationships, after the "Relationships:" word.
#     <</SYS>>
#
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#     ¨
# Indicate by check mark whether the registrant is a large accelerated filer, an accelerated filer, a non-accelerated filer, a smaller reporting
# company, or an emerging growth company. See the definitions of “large accelerated filer,” “accelerated filer,” “smaller reporting company,”
# and "emerging growth company" in Rule 12b-2 of the Exchange Act.
#
#   Large accelerated filer Accelerated filer                    Non-accelerated filer               Smaller reporting company            Emerging growth company
#               ☑                           ¨                                ¨              [/INST]
#      Sure! Here are the entities and relationships extracted from the text:
#
# Entities:
#
# * Registrant (the company that is filing the document)
# * Investor (the person or entity reading the document)
#
# Relationships:
#
# * The registrant is providing information to the investor about its financial status and other relevant details.
# * The investor is using the information provided by the registrant to make informed decisions about investing in the company. [/INST]
#      Correct! Here is the summarized list of entities and relationships in a structured format:
#
# Entities:
#
# * Registrant
# * Investor
#
# Relationships:
#
# * The registrant provides information to the investor about its financial status and other relevant details.
# * The investor uses the information provided by the registrant to make informed decisions about investing in the company.
# Element index 83 of 211:
# Element Summary:
#     <s>[INST] <<SYS>>
#     Summarize the following entities and relationships in a structured format. Use "->" to represent relationships, after the "Relationships:" word.
#     <</SYS>>
#
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#     th company
#               ☑                           ¨                                ¨                                        ☐                                   ☐
# If an emerging growth company, indicate by check mark if the registrant has elected not to use the extended transition period for
# complying with any new or revised financial accounting standards provided pursuant to Section 13(a) of the Exchange Act. ¨
#
# Indicate by check mark whether the registrant is a shell company (as defined in Rule 12b-2 of the Exchange Act).                               Yes ☐      No ☑
# As of April 21, 2023,  [/INST]
#      Sure! Here are the entities and relationships I found in the text:
#
# Entities:
#
# * The Company (not specified)
#
# Relationships:
#
# * The Company has elected not to use the extended transition period for complying with any new or revised financial accounting standards.
# * The Company is not a shell company (defined in Rule 12b-2 of the Exchange Act). [/INST]
#      Correct! Here's the summary you requested:
#
# Entities:
#
# * The Company (not specified)
#
# Relationships:
#
# * The Company has elected not to use the extended transition period for complying with any new or revised financial accounting standards.
# * The Company is not a shell company (defined in Rule 12b-2 of the Exchange Act).
# Element index 84 of 211:
# Element Summary:
#     <s>[INST] <<SYS>>
#     Summarize the following entities and relationships in a structured format. Use "->" to represent relationships, after the "Relationships:" word.
#     <</SYS>>
#
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#     ule 12b-2 of the Exchange Act).                               Yes ☐      No ☑
# As of April 21, 2023, the registrant had outstanding 4,171 million shares of common stock. [/INST]
#      Sure! Here are the entities and relationships that can be extracted from the given text:
#
# Entities:
#
# * Registrant (the company being referred to in the text)
# * Common stock (type of security issued by the registrant)
#
# Relationships:
#
# * As of April 21, 2023 (date as of which the information is accurate)
# * Outstanding (number of shares of common stock that exist at a particular point in time)
# * 4,171 million (number of outstanding shares of common stock) [/INST]
#      Correct! Here's the summary in the requested format:
#
# Entities:
#
# * Registrant (the company being referred to in the text)
# * Common stock (type of security issued by the registrant)
#
# Relationships:
#
# * As of April 21, 2023 (date as of which the information is accurate)
# -> Outstanding (number of shares of common stock that exist at a particular point in time)
# -> 4,171 million (number of outstanding shares of common stock)
# Element index 85 of 211:
# Element Summary:
#     <s>[INST] <<SYS>>
#     Summarize the following entities and relationships in a structured format. Use "->" to represent relationships, after the "Relationships:" word.
#     <</SYS>>
#
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                                                                              UNITED STATES
#                                      SECURITIES AND EXCHANGE COMMISSIONWashington, D.C. 20549
#
#                                                                                 FORM 10-Q
# ☒        QUARTERLY REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934
#          For the Quarterly Period Ended December 31, 2022
#                                                                                                  OR
# ☐        TRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURIT [/INST]
#      Here are the entities and relationships that can be extracted from the given text:
#
# Entities:
#
# 1. United States
# 2. Securities and Exchange Commission (SEC)
# 3. Form 10-Q
# 4. Quarterly period ended December 31, 2022
#
# Relationships:
#
# 1. The text is a quarterly report submitted by the Securities and Exchange Commission (SEC) to the United States government.
# 2. The report is pursuant to Section 13 or 15(d) of the Securities Exchange Act of 1934.
# 3. The report covers the quarterly period ended December 31, 2022. [/INST]
#      Correct! Here's the summary in the requested format:
#
# Entities:
#
# 1. United States
# 2. Securities and Exchange Commission (SEC)
# 3. Form 10-Q
# 4. Quarterly period ended December 31, 2022
#
# Relationships:
#
# 1. The text is a quarterly report submitted by the Securities and Exchange Commission (SEC) to the United States government.
# 2. The report is pursuant to Section 13 or 15(d) of the Securities Exchange Act of 1934.
# 3. The report covers the quarterly period ended December 31, 2022.
# Element index 86 of 211:
# Element Summary:
#     <s>[INST] <<SYS>>
#     Summarize the following entities and relationships in a structured format. Use "->" to represent relationships, after the "Relationships:" word.
#     <</SYS>>
#
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                             OR
# ☐        TRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934
#          For the Transition Period From                 to
#                                                                      Commission File Number 001-37845
#
#                                              MICROSOFT CORPORATION
#                                      WASHINGTON                                                                                         91-1144442
#                               (STATE OF INCORPORATION)                                              [/INST]
#      Here is the extraction of entities and relationships from the given text:
#
# Entities:
#
# 1. Microsoft Corporation (incorporated in Washington state)
# 2. Commission (SEC)
#
# Relationships:
#
# 1. Microsoft Corporation filed a transition report pursuant to Section 13 or 15(d) of the Securities Exchange Act of 1934.
# 2. The Commission (SEC) has a file number for Microsoft Corporation (001-37845). [/INST]
#      Correct! Here's the summary in the requested format:
#
# Entities:
#
# 1. Microsoft Corporation
# 2. Commission (SEC)
#
# Relationships:
#
# 1. Microsoft Corporation filed a transition report pursuant to Section 13 or 15(d) of the Securities Exchange Act of 1934.
# 2. The Commission (SEC) has a file number for Microsoft Corporation (001-37845).
# Element index 87 of 211:
# Element Summary:
#     <s>[INST] <<SYS>>
#     Summarize the following entities and relationships in a structured format. Use "->" to represent relationships, after the "Relationships:" word.
#     <</SYS>>
#
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#
#                               (STATE OF INCORPORATION)                                                                                    (I.R.S. ID)
#                                                          ONE MICROSOFT WAY, REDMOND, WASHINGTON 98052-6399(425) 882-8080
#                                                                              www.microsoft.com/investor
# Securities registered pursuant to Section 12(b) of the Act:
# Title of each class                                                                   Trading Symbol                           Name of exchange on which registered
#  [/INST]
#      Entities:
#         • Microsoft
#             - State of Incorporation: Washington
#             - IRS ID: Not specified
#             - Headquarters: Redmond, Washington
#             - Website: investor.microsoft.com
#
# Relationships:
#
# • None specified [/INST]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Element index 88 of 211:
# Element Summary:
#     <s>[INST] <<SYS>>
#     Summarize the following entities and relationships in a structured format. Use "->" to represent relationships, after the "Relationships:" word.
#     <</SYS>>
#
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                           Trading Symbol                           Name of exchange on which registered
# Common stock, $0.00000625 par value per share                                              MSFT                                                 NASDAQ
# 3.125% Notes due 2028                                                                      MSFT                                                 NASDAQ
# 2.625% Notes due 2033                                                                      MSFT                                                 NASDAQ
# Indicate by check mark whether the registrant ( [/INST]
#      Sure! Here are the entities and relationships that can be extracted from the given text:
#
# Entities:
#
# 1. Microsoft Corporation (MSFT)
# 2. NASDAQ
#
# Relationships:
#
# 1. Microsoft Corporation (MSFT) is listed on NASDAQ.
# 2. The trading symbols for Microsoft Corporation (MSFT) are Common stock and 3.125% Notes due 2028, and 2.625% Notes due 2033.
#
# Note that there are no explicit relationships mentioned in the text between the entities, but the fact that Microsoft Corporation (MSFT) is listed on NASDAQ establishes a relationship between the two. [/INST]
#      Correct! Here is the summary of entities and relationships in a structured format as requested:
#
# Entities:
#
# 1. Microsoft Corporation (MSFT)
# 2. NASDAQ
#
# Relationships:
#
# 1. Microsoft Corporation (MSFT) is listed on NASDAQ.
# 2. The trading symbols for Microsoft Corporation (MSFT) are Common stock and 3.125% Notes due 2028, and 2.625% Notes due 2033.
# Element index 89 of 211:
# Element Summary:
#     <s>[INST] <<SYS>>
#     Summarize the following entities and relationships in a structured format. Use "->" to represent relationships, after the "Relationships:" word.
#     <</SYS>>
#
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#                                                   NASDAQ
# Indicate by check mark whether the registrant (1) has filed all reports required to be filed by Section 13 or 15(d) of the Securities Exchange Act of 1934 during the
# preceding 12 months (or for such shorter period that the registrant was required to file such reports), and (2) has been subject to such filing requirements for the past
# 90 days.    Yes ☒      No ☐
# Indicate by check mark whether the registrant has submitted electronically every Interactive Data File required to be submitted pursuant to Rule 405 of Regulation S-T
# (§232.405 of thi [/INST]
#      Sure! Here are the entities and relationships I found in the text:
#
# Entities:
#
# * NASDAQ
#
# Relationships:
#
# * The registrant is a subsidiary of NASDAQ.
#
# Note: The text does not mention any other entities or relationships. [/INST]
#      Correct! Here's the summary in the requested format:
#
# Entities:
#
# * NASDAQ
#
# Relationships:
#
# * The registrant is a subsidiary of NASDAQ.
#
# Note: There are no other entities or relationships mentioned in the text.
# Element index 90 of 211:
# Element Summary:
#     <s>[INST] <<SYS>>
#     Summarize the following entities and relationships in a structured format. Use "->" to represent relationships, after the "Relationships:" word.
#     <</SYS>>
#
#
#     <s>[INST] <<SYS>>
#     Extract entities and relationships from the following text.
#     <</SYS>>
#
#     teractive Data File required to be submitted pursuant to Rule 405 of Regulation S-T
# (§232.405 of this chapter) during the preceding 12 months (or for such shorter period that the registrant was required to submit such files).                   Yes ☒      No ☐
# Indicate by check mark whether the registrant is a large accelerated filer, an accelerated filer, a non-accelerated filer, a smaller reporting company, or an emerging
# growth company. See the definitions of “large accelerated filer,” “accelerated filer,” “smaller reporting company,” and “emerging growth company” in Rule 12b-2 of the
# Exchan [/INST]
#      Sure! Here are the entities and relationships I found in the text:
#
# Entities:
#
# * Registrant (the company submitting the form)
# * SEC (Securities and Exchange Commission)
#
# Relationships:
#
# * The registrant is required to submit a document to the SEC.
# * The document is required under Rule 405 of Regulation S-T. [/INST]
#      Exactly! Here's the summary you requested, using "->" to represent relationships:
#
# Entities:
#
# * Registrant (the company submitting the form)
# * SEC (Securities and Exchange Commission)
#
# Relationships:
#
# * The registrant -> submits a document to the SEC
# 	+ The document is required under Rule 405 of Regulation S-T
# Element index 91 of 211:
